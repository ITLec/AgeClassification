# %%
import os 
import pandas as pd

# %%
from zipfile import ZipFile
dataset = '/content/drive/MyDrive/Colab Notebooks/11 Age Classification_NEW.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
path = '/content/02 Age Classification/train/adults'
add_text='adult_'
list_files=os.listdir(path)
for files in list_files:
  ext=files.split('.')[1]
  modified_files=add_text+files.split('.')[0]+'.'+ext

  os.rename(os.path.join(path,files),os.path.join(path,modified_files))
  # print(modified_files)

# %%
path = '/content/02 Age Classification/train/children'
add_text='children_'
list_files=os.listdir(path)
for files in list_files:
  ext=files.split('.')[1]

  modified_files=add_text+files.split('.')[0]+'.'+ext

  os.rename(os.path.join(path,files),os.path.join(path,modified_files))
  # print(modified_files)

# %%
import shutil
old_path='/content/02 Age Classification/train/children'
new_path='/content/02 Age Classification/train/adults'
images_children=os.listdir(old_path)
for i in images_children:
  shutil.move(os.path.join(old_path,i), os.path.join(new_path,i))

# %%
path = '/content/02 Age Classification/train/adults'
labels = []
files = []

list_dirc=os.listdir(path)



list_dirc[3].split('_')
for file_name in os.listdir(path):
        if file_name.split('_')[0] == 'adult':
            labels.append(0)
        else:
            labels.append(1)
        files.append(file_name)
#         #files.append(os.path.join(folder_path,file_name)) or can use this 


data_dict = {'files': files, 'class': labels}
data=pd.DataFrame(data_dict)

# %%
data
# Out:
#                 files  class
# 0       adult_394.jpg      0
# 1        adult_84.jpg      0
# 2       adult_127.jpg      0
# 3    children_243.jpg      1
# 4       adult_180.jpg      0
# ..                ...    ...
# 675     adult_171.jpg      0
# 676  children_305.jpg      1
# 677     adult_259.jpg      0
# 678  children_124.jpg      1
# 679     adult_157.jpg      0
#
# [680 rows x 2 columns]

# %%
file_name=list_dirc

# %%
file_name[:3]
# Out:
# ['children_64.jpg', 'children_135.jpg', 'adult_392.jpg']

# %%
import numpy as np
from PIL import Image 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow

# %% [markdown]
# displaing the images

# %%
img=mpimg.imread('/content/02 Age Classification/train/adults/children_104.jpg')
# img

# %%
plt.imshow(img)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=370x320 at 0x7F8D02765720>

# %%
# img

# %%
plt.imshow(img)

# %% [markdown]
# RESIZE  THE IMAGES

# %%
import shutil
path='/content/02 Age Classification/train/adults'
images=os.listdir(path)
# for i in images:
#   shutil.move(os.path.join(old_path,i), os.path.join(new_path,i))

# %%
images[:10]
# Out:
# ['adult_394.jpg',
#  'adult_84.jpg',
#  'adult_127.jpg',
#  'children_243.jpg',
#  'adult_180.jpg',
#  'children_271.jpg',
#  'adult_159.jpg',
#  'children_193.jpg',
#  'adult_114.jpg',
#  'children_312.jpg']

# %%
from PIL import Image

path = '/content/02 Age Classification/train/adults'
output_path = '/content/02 Age Classification/train/adults_resized'

# Create the output folder if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Get the list of image files in the folder
images = os.listdir(path)

# Loop through each image file and resize it
for image_file in images:
    image_path = os.path.join(path, image_file)
    output_image_path = os.path.join(output_path, image_file)

    # Open the image using PIL
    image = Image.open(image_path)

    # Resize the image
    resized_image = image.resize((224, 224))  # Replace new_width and new_height with the desired dimensions

    # Save the resized image
    resized_image.save(output_image_path)

    # Optionally, you can also delete the original image
    # os.remove(image_path)

# %%
img=mpimg.imread('/content/02 Age Classification/train/adults_resized/adult_104.jpg')

plt.imshow(img)

# %%
import cv2 as cv

# %%
img=cv.imread('/content/02 Age Classification/train/adults_resized/adult_104.jpg')

plt.imshow(img)

# %%
filenames=os.listdir('/content/02 Age Classification/train/adults_resized')

# %%
path ='/content/02 Age Classification/train/adults_resized'
labels = []
files = []

list_dirc=os.listdir(path)



list_dirc[3].split('_')
for file_name in os.listdir(path):
        if file_name.split('_')[0] == 'adult':
            labels.append(0)
        else:
            labels.append(1)
        files.append(file_name)
#         #files.append(os.path.join(folder_path,file_name)) or can use this 


data_dict = {'files': files, 'class': labels}
data=pd.DataFrame(data_dict)

# %%
data
# Out:
#                 files  class
# 0       adult_394.jpg      0
# 1        adult_84.jpg      0
# 2       adult_127.jpg      0
# 3    children_243.jpg      1
# 4       adult_180.jpg      0
# ..                ...    ...
# 675     adult_171.jpg      0
# 676  children_305.jpg      1
# 677     adult_259.jpg      0
# 678  children_124.jpg      1
# 679     adult_157.jpg      0
#
# [680 rows x 2 columns]

# %%
data[data['files']=='adult_100.jpg']
# Out:
#              files  class
# 607  adult_100.jpg      0

# %%
import cv2 as cv

# %%
images_array=[]
dirct='/content/02 Age Classification/train/adults_resized'

for file in os.listdir(dirct):
 
  images_array.append(cv.imread(os.path.join(dirct,file)))

# images_array.shape

# %%
images_array[:10]
# Out:
# [array([[[210, 206, 201],
#          [210, 206, 201],
#          [210, 206, 201],
#          ...,
#          [242, 240, 230],
#          [246, 242, 231],
#          [232, 228, 217]],
#
#         [[210, 206, 201],
#          [210, 206, 201],
#          [210, 206, 201],
#          ...,
#          [233, 231, 221],
#          [237, 233, 222],
#          [229, 225, 214]],
#
#         [[210, 206, 201],
#          [210, 206, 201],
#          [210, 206, 201],
#          ...,
#          [208, 206, 196],
#          [213, 209, 198],
#          [211, 207, 196]],
#
#         ...,
#
#         [[186, 179, 164],
#          [187, 180, 165],
#          [188, 181, 166],
#          ...,
#          [194, 189, 174],
#          [193, 188, 173],
#          [191, 186, 171]],
#
#         [[183, 176, 161],
#          [184, 177, 162],
#          [186, 179, 164],
#          ...,
#          [191, 187, 169],
#          [189, 185, 167],
#          [186, 182, 164]],
#
#         [[181, 174, 159],
# ...

# %%
np.shape(images_array)
# Out:
# (680, 224, 224, 3)

# %%
images_array=np.asarray(images_array)

# %%
images_array.shape
# Out:
# (680, 224, 224, 3)

# %%
X=images_array
y=np.asarray(labels)

# %%
# y

# %%
# print(X[:1])
# print(y[:1])

# %%
imgae_adult=cv.imread('/content/02 Age Classification/train/adults_resized/adult_100.jpg')


plt.imshow(imgae_adult)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=44, shuffle =True)

# Splitted Data
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (612, 224, 224, 3)
# X_test shape is  (68, 224, 224, 3)
# y_train shape is  (612,)
# y_test shape is  (68,)

# %%
y[:12]
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 1, 0, 0, 1, 0])

# %%
# plt.imread(X_train{:1})
# plt.imshow(X_train[:1])

# %%
# data_dict={}
# print(X_train[:2])
# y_train[:2]
# data_={'data':X_train,'class':y_train}
# pd.DataFrame(data_)

# %% [markdown]
# scling the data

# %%
# Determine the number of augmented images
# num_augmented_images = len(datagen.flow(X_train, batch_size=1))

# # Determine the total number of images
# num_total_images = len(X_train)

# print("Number of augmented images:", num_augmented_images)
# print("Total number of images:", num_total_images)

# %%
X_train_scaled=X_train/255
X_test_scaled=X_test/255

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.applications.resnet50 import  ResNet50

# %%
# from keras.applications import ResNet50

# RES = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# RES.trainable = False

# RES.summary()

# %%
mobilenet_model = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'
pretrained_model=hub.KerasLayer(mobilenet_model,input_shape=(224,224,3),trainable=True)# when  false dont update the weights of the pretraied model

# %%
from tensorflow.keras import Sequential,models,layers
from tensorflow.keras.layers import Dense,Dropout,Flatten,BatchNormalization

from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model

# %%
class_num=1
# from keras.layers import Input
model = tf.keras.Sequential([
    pretrained_model,
    # tf.keras.layers.Dense(256, activation='relu'),
    # tf.keras.layers.Dropout(0.5),
        # tf.keras.layers.Dense(128, activation='relu'),
    # tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(class_num, activation='sigmoid')
])

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='best_weights.h5',
    save_best_only=True,
    
    monitor='val_accuracy',  
    mode='max', 
    verbose=1
)

# %%
model.compile(optimizer='adam', loss='BinaryCrossentropy', metrics=['accuracy'])

# %%
# model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
# ,learning_rate_reduction
history=model.fit(X_train_scaled, y_train,epochs=100,
verbose=1,validation_data=(X_test_scaled,y_test),callbacks=[checkpoint_callback,learning_rate_reduction])
# Out:
# Epoch 1/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.7353
# Epoch 1: val_accuracy improved from -inf to 0.52941, saving model to best_weights.h5
# 20/20 [==============================] - 34s 248ms/step - loss: 0.6885 - accuracy: 0.7353 - val_loss: 4.2447 - val_accuracy: 0.5294 - lr: 0.0010
# Epoch 2/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3588 - accuracy: 0.8964
# Epoch 2: val_accuracy improved from 0.52941 to 0.75000, saving model to best_weights.h5
# 20/20 [==============================] - 3s 162ms/step - loss: 0.3584 - accuracy: 0.8954 - val_loss: 1.7031 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 3/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1794 - accuracy: 0.9688
# Epoch 3: val_accuracy did not improve from 0.75000
# 20/20 [==============================] - 3s 137ms/step - loss: 0.1788 - accuracy: 0.9690 - val_loss: 2.2651 - val_accuracy: 0.6618 - lr: 0.0010
# Epoch 4/100
# ...

# %%
import tensorflow as tf

# %%
The_Model=model.save('/content/best_weights.h5')

# %%
from keras.models import load_model
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow_hub import KerasLayer # import the hub.KerasLayer class

model_95 = keras.models.load_model('/content/best_weights_955.h5', custom_objects={'KerasLayer': hub.KerasLayer})

# %%
model_95.history['val_accuracy']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-9cd6c322184c> in <cell line: 1>()
# ----> 1 model_95.history['val_accuracy']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
pd.Series(history.history['val_accuracy']).value_counts()
# Out:
# 0.926471    65
# 0.941176    12
# 0.955882     5
# 0.911765     4
# 0.750000     2
# 0.808824     2
# 0.852941     2
# 0.529412     1
# 0.661765     1
# 0.823529     1
# 0.764706     1
# 0.705882     1
# 0.838235     1
# 0.882353     1
# 0.897059     1
# dtype: int64

# %%
max(pd.Series(history.history['val_accuracy']).value_counts().index)
# Out:
# 0.9558823704719543

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 100, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 100, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np

# %%
path = '/content/02 Age Classification/test/adults'
add_text='adult_'
list_files=os.listdir(path)
for files in list_files:
  ext=files.split('.')[1]
  modified_files=add_text+files.split('.')[0]+'.'+ext

  os.rename(os.path.join(path,files),os.path.join(path,modified_files))
  # print(modified_files)

# %%
path = '/content/02 Age Classification/test/children'
add_text='children_'
list_files=os.listdir(path)
for files in list_files:
  ext=files.split('.')[1]

  modified_files=add_text+files.split('.')[0]+'.'+ext

  os.rename(os.path.join(path,files),os.path.join(path,modified_files))
  # print(modified_files)

# %%
import shutil
old_path='/content/02 Age Classification/test/children'
new_path='/content/02 Age Classification/test/adults'
images_children=os.listdir(old_path)
for i in images_children:
  shutil.move(os.path.join(old_path,i), os.path.join(new_path,i))

# %%
from PIL import Image

path = '/content/02 Age Classification/test/adults'
output_path = '/content/02 Age Classification/test/adults_resized'

# Create the output folder if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Get the list of image files in the folder
images = os.listdir(path)

# Loop through each image file and resize it
for image_file in images:
    image_path = os.path.join(path, image_file)
    output_image_path = os.path.join(output_path, image_file)

    # Open the image using PIL
    image = Image.open(image_path)

    # Resize the image
    resized_image = image.resize((224, 224))  # Replace new_width and new_height with the desired dimensions

    # Save the resized image
    resized_image.save(output_image_path)

    # Optionally, you can also delete the original image
    # os.remove(image_path)

# %%
path ='/content/02 Age Classification/test/adults_resized'
labels = []
files = []

list_dirc=os.listdir(path)



list_dirc[3].split('_')
for file_name in os.listdir(path):
        if file_name.split('_')[0] == 'adult':
            labels.append(0)
        else:
            labels.append(1)
        files.append(file_name)
#         #files.append(os.path.join(folder_path,file_name)) or can use this 


data_dict = {'files': files, 'class': labels}
data=pd.DataFrame(data_dict)

# %%
data
# Out:
#                files  class
# 0        adult_4.jpg      0
# 1    children_41.jpg      1
# 2    children_44.jpg      1
# 3       adult_34.jpg      0
# 4       adult_52.jpg      0
# ..               ...    ...
# 115   children_2.jpg      1
# 116  children_47.jpg      1
# 117     adult_43.jpg      0
# 118   children_0.jpg      1
# 119  children_45.jpg      1
#
# [120 rows x 2 columns]

# %%
images_array=[]
dirct='/content/02 Age Classification/test/adults_resized'

for file in os.listdir(dirct):
 
  images_array.append(cv.imread(os.path.join(dirct,file)))

# images_array.shape

# %%
X=images_array
y=np.asarray(labels)

# %%
X_arr=np.array(X)

# %%
X_test_scaled=(X_arr)/255

# %%
import numpy as np
probabilities = model.predict(X_test_scaled) # Get probabilities
predictions = np.where(probabilities > 0.16161616161616163, 1, 0) # Apply threshold
# Out:
# 4/4 [==============================] - 0s 42ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y, predictions))
print(classification_report(y, predictions))
# Out:
# [[46 14]
#  [ 7 53]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.81        60
#            1       0.79      0.88      0.83        60
#
#     accuracy                           0.82       120
#    macro avg       0.83      0.82      0.82       120
# weighted avg       0.83      0.82      0.82       120

# %%
from sklearn.metrics import precision_recall_fscore_support

# Calculate probabilities
probabilities = model.predict(X_test_scaled)

# Calculate precision, recall, and F1-score for different thresholds
thresholds = np.linspace(0, 1, num=100)  # Generate a range of thresholds
f1_scores = []
for threshold in thresholds:
    predictions = np.where(probabilities > threshold, 1, 0)
    _, _, f1_, _ = precision_recall_fscore_support(y, predictions, average='binary')
    f1_scores.append(f1_)

# Find the threshold with the best F1-score
best_threshold_index = np.argmax(f1_scores)
best_threshold = thresholds[best_threshold_index]
best_f1_score = f1_scores[best_threshold_index]

# Use the best threshold for final predictions
final_predictions = np.where(probabilities > best_threshold, 1, 0)

print("Best Threshold:", best_threshold)
print("Best F1-score:", best_f1_score)
# Out:
# 4/4 [==============================] - 1s 46ms/step
# Best Threshold: 0.16161616161616163
# Best F1-score: 0.8346456692913385
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
back_1d_prediction=predictions.ravel()

# %%
Data_prediciotns=pd.DataFrame({'files':files,'prediction':back_1d_prediction,'RealClassification':y})

# %%
Data_prediciotns
# Out:
#                files  prediction  RealClassification
# 0        adult_4.jpg           0                   0
# 1    children_41.jpg           1                   1
# 2    children_44.jpg           1                   1
# 3       adult_34.jpg           0                   0
# 4       adult_52.jpg           0                   0
# ..               ...         ...                 ...
# 115   children_2.jpg           1                   1
# 116  children_47.jpg           1                   1
# 117     adult_43.jpg           1                   0
# 118   children_0.jpg           1                   1
# 119  children_45.jpg           1                   1
#
# [120 rows x 3 columns]

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Get the path of the image to be predicted
input_image_path = input('Path of the image to be predicted: ')

# Read the image
input_image = cv2.imread(input_image_path)

# Resize the image to 224x224 pixels
input_image_resize = cv2.resize(input_image, (224, 224))

# Scale the image to the range [0, 1]
input_image_scaled = input_image_resize / 255

# Reshape the image to a 4D tensor
image_reshaped = np.reshape(input_image_scaled, [1, 224, 224, 3])

input_prediction = model.predict(image_reshaped)
if input_prediction>0.16161616161616163:
  print("this phoo represent child")
else:
    print("this photo represent adult")



print('The image represents ', input_prediction)
cv2_imshow(input_image)
# Out:
# Path of the image to be predicted: /content/02 Age Classification/test/adults/adult_12.jpg
# 1/1 [==============================] - 0s 23ms/step
# this photo represent adult
# The image represents  [[1.0889182e-06]]
# <PIL.Image.Image image mode=RGB size=370x320 at 0x7F8CE81953F0>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Get the path of the image to be predicted
input_image_path = input('Path of the image to be predicted: ')

# Read the image
input_image = cv2.imread(input_image_path)

# Resize the image to 224x224 pixels
input_image_resize = cv2.resize(input_image, (224, 224))

# Scale the image to the range [0, 1]
input_image_scaled = input_image_resize / 255

# Reshape the image to a 4D tensor
image_reshaped = np.reshape(input_image_scaled, [1, 224, 224, 3])

input_prediction = model.predict(image_reshaped)
if input_prediction>0.16161616161616163:
  print("this photo represent child")
else:
    print("this photo represent adult")





print('The image represents ', input_prediction)
cv2_imshow(input_image)
# Out:
# Path of the image to be predicted: /content/02 Age Classification/test/adults/children_24.jpg
# 1/1 [==============================] - 0s 24ms/step
# this photo represent child
# The image represents  [[0.990608]]
# <PIL.Image.Image image mode=RGB size=370x320 at 0x7F8CF011C610>
